# %% [markdown]
# # Function Showcase

# %% [markdown]
# #### Import libraries
# The functions we will use inhabit the ``` internal ``` module

# %%
import os, sys
sys.path.insert(1, os.getcwd()+'/..')
from internal import *

# %% [markdown]
# ## Generator Functions
# We use the functions:
# ```bash
# generate_frequencies
# generate_amplitudes
# generate_phase
# generate_signal
# ```
# to generate the synthetical signals.
# - ```generate_frequencies``` randomly generates ```N``` frequencies
# - ```generate_amplitudes``` randomly generates ```N``` amplitudes
# - ```generate_phases``` randomly generates ```N``` phases
# - ```generate_signal``` Takes a set of frequencies, amplitudes and phases, creating a sinusoidal wave with each of them and adding them all together to create a signal. This function also uses a given signal duration and sampling rate

# %% [markdown]
# ### Setting the parameters

# %%
sr = 100;       # Hz. Sampling rate
t = 10;         # s. Duration of the signal
n_bins = 1000;  # Number of bins to use for the DFT calculation
N = 1000;       # Number of different frequencies composing the signal

# %% [markdown]
# ### Generate the signal

# %%
freq = generate_frequencies(N, sigma=0.25, f0=25, sr=sr);
A = generate_amplitudes(N, sigma= 10);
phi = generate_phase(N)
x, y = generate_signal(freq, A, t=t, phi=phi, sr=sr);

# %% [markdown]
# #### Add high frequency noise
# We can also use the generator funtions to add characteristincs to our artificial signal. For example, we can add random high frequency noise:

# %%
AN = generate_amplitudes(10);
f0 = np.random.normal(40, 0.1, 10)
_, noise = generate_signal(f0, AN, t=t, sr=sr)
y += noise;
f0
# Out:
# array([40.12143638, 39.918727  , 39.99321571, 39.90400902, 40.02726355,
#        39.9294451 , 40.07522587, 40.06296019, 39.94113105, 39.96498371])

# %% [markdown]
# ## The Processor class
# We have created a class called ```Processor``` that allows us to handle and process any given signal. This class takes as input the signal and its sampling rate.

# %%
signal = Processor(y, sr)
signal.check()
# Out:
#         signal duration: 10.0 s
#         sample rate:     100 Hz
#         Nº samples:      1000

# %% [markdown]
# The ```Processor``` class contains several methods based on the rest of the functions in ```internal```. These functions enable the user to plot the signal, calculate the its FFT, run tests like energy conservation based on Parseval's theorem and set windows along the signal, segmenting the FFT calculations.

# %%
signal.plot_signal();

# %% [markdown]
# #### About the FFT:
# When calculating the FFT we keep both the imaginary and real part.
# When plotting we consider only positive frequencies and can choose between plotting the imaginary and real part separately of plotting the module (default option)

# %%
signal.fft(n_bins)
signal.Parseval()
signal.plot_fft();
# Out:
#         Energy time domain:      2899551219.7831306
#         Energy frequency domain: 2899551219.7831306
#         Ratio:                   1.0

# %% [markdown]
# ### STFT
# The Short Time Fourier Transform (STFT) of a signal is the FFT calculated in several different windows along the signal. To caluclate we make use of the class ``ShortTimeFFT`` from ````scipy.signal````. The Processor class is a child class of this class.

# %%
signal.set_stft(window_duration=1)
signal.spectrogram()
signal.plot_spectrogram();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 signal.set_stft(window_duration=1)
#       2 signal.spectrogram()
# ----> 3 signal.plot_spectrogram();
#
# File c:\Users\Jesús\Documents\GitHub\STFT-MEDA\reports/..\internal\Processor.py:143, in Processor.plot_spectrogram(self)
#     142 def plot_spectrogram(self):
# --> 143     return plot.spectrogram(self.t(), self.fftfreq(),self.Sxx)
#
# TypeError: ShortTimeFFT.t() missing 1 required positional argument: 'n'

# %%
# Out:
# array([[8.62638943e+06, 9.72649496e+04, 4.66191240e+06, 2.06033919e+05,
#         4.60296642e+06, 1.52774885e+05, 4.65541707e+06, 1.99278906e+02,
#         3.86560483e+01, 2.97306596e+06, 2.46926122e+06],
#        [2.86161242e+04, 1.02529097e+05, 4.68658160e+06, 2.09000932e+05,
#         4.63795280e+06, 1.55209272e+05, 4.67209427e+06, 5.86929118e+03,
#         8.78677651e+01, 2.98205050e+06, 1.68566451e+05],
#        [8.73101727e+06, 1.18545935e+05, 4.76145668e+06, 2.18024467e+05,
#         4.74422085e+06, 1.62606807e+05, 4.72263881e+06, 2.31307997e+04,
#         2.38002483e+02, 3.00926031e+06, 2.52597308e+06],
#        [3.09504711e+04, 1.46005777e+05, 4.88920233e+06, 2.33481389e+05,
#         4.92579264e+06, 1.75257326e+05, 4.80862414e+06, 5.27578905e+04,
#         4.96779979e+02, 3.05548074e+06, 1.71332708e+05],
#        [9.05696732e+06, 1.86118377e+05, 5.07447486e+06, 2.56032296e+05,
#         5.18970110e+06, 1.93667060e+05, 4.93279231e+06, 9.61088028e+04,
#         8.77835271e+02, 3.12207848e+06, 2.70438028e+06],
#        [3.59476482e+04, 2.40709751e+05, 5.32427298e+06, 2.86674648e+05,
#         5.54652725e+06, 2.18596315e+05, 5.09924858e+06, 1.55237406e+05,
#         1.40198999e+03, 3.21109550e+06, 1.77112102e+05],
#        [9.64370465e+06, 3.12375215e+05, 5.64849084e+06, 3.26826879e+05,
#         6.01124713e+06, 2.51118561e+05, 5.31376708e+06, 2.33069840e+05,
#         2.09929593e+03, 3.32539631e+06, 3.03180235e+06],
#        [4.43599105e+04, 4.04710368e+05, 6.06074955e+06, 3.78455560e+05,
#         6.60450501e+06, 2.92708753e+05, 5.58424860e+06, 3.33671908e+05,
#         3.01218631e+03, 3.46888826e+06, 1.86456390e+05],
#        [1.05695338e+07, 5.22655236e+05, 6.57963098e+06, 4.44265267e+05,
#         7.35450204e+06, 3.45373296e+05, 5.92139658e+06, 4.62648909e+05,
#         4.20029557e+03, 3.64684609e+06, 3.56346459e+06],
#        [5.76042869e+04, 6.73008790e+05, 7.23051418e+06, 5.27983207e+05,
#         8.29980584e+06, 4.11841560e+05, 6.33971804e+06, 6.27745932e+05,
#         5.74789004e+03, 3.86639178e+06, 2.00365298e+05],
#        [1.19775266e+07, 8.65208202e+05, 8.04834389e+06, 6.34791651e+05,
#         9.49358192e+06, 4.95851056e+05, 6.85902439e+06, 8.39761321e+05,
#         7.77552598e+03, 4.13721269e+06, 4.40291572e+06],
#        [7.82942515e+04, 1.11253200e+06, 9.08188499e+06, 7.71998106e+05,
#         1.10100878e+07, 6.02579239e+05, 7.50672519e+06, 1.11396454e+06,
#         1.04587875e+04, 4.47265758e+06, 2.20590951e+05],
#        [1.41328677e+07, 1.43400386e+06, 1.04004235e+07, 9.50100442e+05,
#         1.29548813e+07, 7.39311563e+05, 8.32142148e+06, 1.47235288e+06,
#         1.40593203e+04, 4.89145169e+06, 5.74818481e+06],
#        [1.11449838e+05, 1.85749482e+06, 1.21046373e+07, 1.18453169e+06,
#         1.54813377e+07, 9.16502221e+05, 9.35870491e+06, 1.94735307e+06,
#         1.89781027e+04, 5.42046310e+06, 2.50301732e+05],
#        [1.75588076e+07, 2.42495715e+06, 1.43448573e+07, 1.49862234e+06,
#         1.88182991e+07, 1.14951048e+06, 1.07008530e+07, 2.58811219e+06,
#         2.58508469e+04, 6.09932820e+06, 8.00392443e+06],
#        [1.67513019e+05, 3.20162350e+06, 1.73530359e+07, 1.92884712e+06,
#         2.33182529e+07, 1.46154597e+06, 1.24737282e+07, 3.47164687e+06,
#         3.57276755e+04, 6.98852225e+06, 2.95666827e+05],
#        [2.34007184e+07, 4.29298185e+06, 2.15015179e+07, 2.53459898e+06,
#         2.95453681e+07, 1.88887752e+06, 1.48777347e+07, 4.72361257e+06,
#         5.04326174e+04, 8.18417469e+06, 1.20895124e+07],
#        [2.70935985e+05, 5.87798982e+06, 2.74176555e+07, 3.41754504e+06,
#         3.84458144e+07, 2.49051194e+06, 1.82480318e+07, 6.55939277e+06,
#         7.33379267e+04, 9.84698931e+06, 3.70220849e+05],
#        [3.45927296e+07, 8.27891666e+06, 3.62241364e+07, 4.76297004e+06,
#         5.17011052e+07, 3.36727680e+06, 2.31806316e+07, 9.37163743e+06,
#         1.11192047e+05, 1.22631388e+07, 2.04523768e+07],
#        [4.89627488e+05, 1.21221546e+07, 5.00911353e+07, 6.93700601e+06,
#         7.25282325e+07, 4.70227086e+06, 3.08223187e+07, 1.39350589e+07,
#         1.78970436e+05, 1.59853871e+07, 5.09844121e+05],
#        [6.07812953e+07, 1.87550342e+07, 7.36656581e+07, 1.07463083e+07,
#         1.07709298e+08, 6.85473093e+06, 4.36240309e+07, 2.19480445e+07,
#         3.14896385e+05, 2.22039846e+07, 4.14574457e+07],
#        [1.06551528e+06, 3.15166394e+07, 1.18430070e+08, 1.82662748e+07,
#         1.73597551e+08, 1.06047407e+07, 6.76591388e+07, 3.77287339e+07,
#         6.38026511e+05, 3.39065134e+07, 8.48924285e+05],
#        [1.52191487e+08, 6.06651711e+07, 2.19646045e+08, 3.62988163e+07,
#         3.18366557e+08, 1.78979075e+07, 1.21814460e+08, 7.50501670e+07,
#         1.65160771e+06, 6.05838620e+07, 1.20451764e+08],
#        [3.04693447e+06, 1.52149349e+08, 5.36081444e+08, 9.95575718e+07,
#         7.41557544e+08, 3.46193886e+07, 2.94550226e+08, 1.99748235e+08,
#         6.97753775e+06, 1.48303803e+08, 2.90524692e+06],
#        [1.26199512e+09, 8.58739275e+08, 3.02822483e+09, 7.71138690e+08,
#         3.35540031e+09, 6.17561010e+07, 1.97265604e+09, 1.37490484e+09,
#         9.12010272e+07, 1.08292038e+09, 1.35393841e+09],
#        [3.11724575e+09, 2.02794473e+10, 1.85757291e+10, 2.99823688e+10,
#         2.08340261e+08, 3.22672202e+10, 3.59848954e+09, 3.06175032e+09,
#         2.11874547e+10, 3.14977218e+09, 3.36049637e+09],
#        [1.31402597e+09, 1.19503216e+09, 3.23905619e+09, 5.01196741e+08,
#         5.80522631e+09, 1.45311314e+09, 9.01053394e+08, 5.16441712e+08,
#         1.69937300e+08, 1.46835484e+08, 1.41976106e+09],
#        [2.03506894e+07, 1.90655703e+08, 5.66825129e+08, 1.09917896e+08,
#         1.06972245e+09, 1.67860398e+08, 2.06138753e+08, 1.69994523e+08,
#         8.74615987e+06, 5.10605033e+07, 2.57330999e+06],
#        [1.05875850e+08, 8.39322548e+07, 2.50543208e+08, 4.79626566e+07,
#         4.64657680e+08, 6.08887634e+07, 9.07866782e+07, 8.37824221e+07,
#         2.48096738e+06, 2.38727048e+07, 1.50341482e+08],
#        [5.17926364e+06, 4.85968442e+07, 1.45007437e+08, 2.79746733e+07,
#         2.65849666e+08, 3.17591758e+07, 5.07727506e+07, 5.11326357e+07,
#         1.21091004e+06, 1.31688509e+07, 5.51255888e+05],
#        [3.34849239e+07, 3.22638599e+07, 9.65592486e+07, 1.89320966e+07,
#         1.75442559e+08, 1.97831929e+07, 3.22964082e+07, 3.51677827e+07,
#         7.73113909e+05, 8.01926223e+06, 5.75774795e+07],
#        [3.73160366e+06, 2.32529240e+07, 7.02495046e+07, 1.40521235e+07,
#         1.26469126e+08, 1.36769318e+07, 2.22768295e+07, 2.61049593e+07,
#         5.78553184e+05, 5.20108236e+06, 3.74284950e+05],
#        [1.49962651e+07, 1.76798391e+07, 5.44137311e+07, 1.11316816e+07,
#         9.68427224e+07, 1.01155608e+07, 1.62414797e+07, 2.04309201e+07,
#         4.82662748e+05, 3.51644449e+06, 3.18303639e+07],
#        [4.44230950e+06, 1.39299146e+07, 4.42404120e+07, 9.27894947e+06,
#         7.75047545e+07, 7.83265923e+06, 1.23201403e+07, 1.66239438e+07,
#         4.38632766e+05, 2.44305629e+06, 4.65619446e+05],
#        [7.92021797e+06, 1.12204578e+07, 3.74692864e+07, 8.08550522e+06,
#         6.41665490e+07, 6.25646179e+06, 9.61610788e+06, 1.39352824e+07,
#         4.30725007e+05, 1.72599954e+06, 2.11626399e+07],
#        [7.83018762e+06, 9.11812874e+06, 3.29725968e+07, 7.36322018e+06,
#         5.45793736e+07, 5.09238587e+06, 7.65253738e+06, 1.19621676e+07,
#         4.58513322e+05, 1.23089532e+06, 7.98775847e+05],
#        [4.61498953e+06, 7.33955284e+06, 3.02447883e+07, 7.06356594e+06,
#         4.74716275e+07, 4.16657465e+06, 6.15251029e+06, 1.04781445e+07,
#         5.37736970e+05, 8.85485157e+05, 1.58912092e+07],
#        [2.22296401e+07, 5.63785567e+06, 2.93275714e+07, 7.31393012e+06,
#         4.20833800e+07, 3.35237197e+06, 4.94437164e+06, 9.37376041e+06,
#         7.21725565e+05, 6.61071912e+05, 1.95813907e+06],
#        [2.92937746e+06, 3.67727444e+06, 3.14461496e+07, 8.77583562e+06,
#         3.79379447e+07, 2.51573086e+06, 3.95943170e+06, 8.73445743e+06,
#         1.21310081e+06, 6.07479544e+05, 1.35070717e+07],
#        [2.19053811e+08, 9.47459445e+05, 4.51161101e+07, 1.60407114e+07,
#         3.45023908e+07, 1.49626091e+06, 4.02067877e+06, 1.01774837e+07,
#         3.36436360e+06, 1.32442174e+06, 1.40684170e+07],
#        [6.52897390e+08, 1.73608877e+09, 7.45031871e+08, 1.22484487e+08,
#         4.93013125e+08, 4.29474398e+08, 4.02572466e+08, 3.85476165e+08,
#         3.88081826e+08, 2.79135211e+08, 8.59141998e+07],
#        [2.79238209e+08, 2.51476490e+07, 2.02368380e+06, 5.12505313e+06,
#         2.82454923e+07, 1.08283389e+07, 1.54861145e+07, 1.66512992e+07,
#         3.64715088e+06, 4.41446543e+06, 1.66462260e+07],
#        [9.38581659e+05, 1.34871480e+07, 4.93393941e+06, 1.65706688e+06,
#         2.68309032e+07, 5.80937020e+06, 7.63876211e+06, 9.59495936e+06,
#         6.26356659e+05, 1.25415459e+06, 7.05672177e+06],
#        [3.63670914e+07, 1.04416529e+07, 6.49612193e+06, 1.46288844e+06,
#         2.56294861e+07, 4.56243293e+06, 5.73815051e+06, 7.96808565e+06,
#         2.12393368e+05, 6.47393217e+05, 1.24189210e+06],
#        [6.22048160e+05, 9.01142336e+06, 7.18020358e+06, 1.47968273e+06,
#         2.45984054e+07, 3.97699477e+06, 4.86086592e+06, 7.20981376e+06,
#         9.37782636e+04, 4.02447205e+05, 6.93920735e+06],
#        [1.65164695e+07, 8.17882816e+06, 7.48496493e+06, 1.50709217e+06,
#         2.37539379e+07, 3.63295696e+06, 4.34950608e+06, 6.75539427e+06,
#         4.79052912e+04, 2.71423162e+05, 2.91619165e+05],
#        [4.19327007e+05, 7.64635118e+06, 7.61604932e+06, 1.52503344e+06,
#         2.30869234e+07, 3.41065909e+06, 4.02039789e+06, 6.45432607e+06,
#         2.70553394e+04, 1.91799568e+05, 6.64015266e+06],
#        [1.11286976e+07, 7.29579360e+06, 7.66620817e+06, 1.53471398e+06,
#         2.25839809e+07, 3.26303652e+06, 3.80229930e+06, 6.24985489e+06,
#         1.66691731e+04, 1.41051344e+05, 7.33852883e+04],
#        [3.07770119e+05, 7.07173863e+06, 7.68066797e+06, 1.53930454e+06,
#         2.22333563e+07, 3.16807495e+06, 3.66216927e+06, 6.11603175e+06,
#         1.13163531e+04, 1.09284740e+05, 6.44057014e+06],
#        [9.37234697e+06, 6.94621147e+06, 7.68221569e+06, 1.54117054e+06,
#         2.20264301e+07, 3.11464812e+06, 3.58338406e+06, 6.03986985e+06,
#         8.72896421e+03, 9.17106055e+04, 9.51246011e+03],
#        [2.72282028e+05, 6.90571822e+06, 7.68166442e+06, 1.54165030e+06,
#         2.19580278e+07, 3.09737769e+06, 3.55792466e+06, 6.01510919e+06,
#         7.95488543e+03, 8.60753250e+04, 6.37299756e+06]])
